# %% [markdown]
# <a href="https://colab.research.google.com/github/dragon7268/ABCD-A/blob/20250328/%ED%8C%8C%EC%9D%B4%EC%8D%AC300%EC%A0%9C_11_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자 = 50000

주식수 = 10

총평가금액 = 삼성전자 * 주식수

print("총 평가금액:", 총평가금액, "원")
# Out:
# 총 평가금액: 500000 원

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print("시가총액:", 시가총액, "원")
print("현재가:", 현재가, "원")
print("PER", PER)
# Out:
# 시가총액: 298000000000000 원
# 현재가: 50000 원
# PER 15.79

# %%
s = "hello"
t = "python"
print(s,t)
# Out:
# hello python

# %%
a = 2
b = 3
print( a + a * b)
# Out:
# 8
